# %%
# !python --version
# Out:
# Python 3.8.8

# %% [markdown]
# # LGMVIP-DataScience

# %% [markdown]
# # TASK2

# %% [markdown]
# # Author : Anupam Tudu

# %% [markdown]
# # Image to Pencil Sketch with Python

# %%
import cv2 # opencv is an open source library which provides us with numerous
           # computer vision algorithms
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the image from the directory

# %%
img = cv2.imread("flower.jpg")
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), cmap='gray')
plt.show()

# %% [markdown]
# ## Grayscaling the image

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_img)
plt.title("Grayscaled Image")
plt.show()

# %% [markdown]
# ## Inverting the grayscale image

# %%
inv_img = 255 - gray_img
plt.imshow(inv_img)
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# ## Blurring the inverted image

# %%
blur = cv2.GaussianBlur(inv_img, (21, 21), 0)
plt.figure(figsize=(10, 10))
plt.imshow(blur)
plt.show()

# %% [markdown]
# inv_blur = 255 - blur
# p_sk = cv2.divide(gray_img, inv_blur, scale=256.0)
# plt.figure(figsize=(10, 10))
# plt.
